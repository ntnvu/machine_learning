# %%
# %config IPCompleter.greedy = True
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Tahoma', 'DejaVu Sans',
                               'Lucida Grande', 'Verdana']

import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot([1, 2, 3], label='line1', marker='*', markersize=10)
ax.plot([1.5, 2.5, 3.5], label='line2')
ax.set_title("Line song song")
# thêm ghi chú label
ax.legend(title="Ghi chú line")
# Làm chữ mờ (Watermark)
# position bottom right
fig.text(0.95, 0.05, 'Line song song',
         fontsize=40, color='gray',
         ha='right', va='bottom', alpha=0.5)

plt.show()

#1 #2

# %%
# Fixing random state for reproducibility
import numpy as np
np.random.seed(19680801)


plt.rcParams['axes.unicode_minus'] = False
fig, ax = plt.subplots()
ax.plot(10*np.random.randn(100), 10*np.random.randn(100), 'o')
ax.set_title('Using hyphen instead of Unicode minus')
plt.show()

# %%
x = [1,3,5]
y = [3,5,7]

plt.plot(x,y, color="red", linewidth=2.5, linestyle="-")

plt.title('Tên biểu đồ', color="red")
plt.ylabel('Trục tung', color="green")
plt.xlabel('Trục hoành', color="green")
# lưới
plt.grid(True,color='k')

plt.show()

# %%
# thiết lập giới hạn cho các trục
#linestyle: '-', '--', ':', '-.'

height = [1.6, 1.7, 1.8, 1.9, 1.5, 1.6]
plt.plot(height, color="blue", linewidth=1.5, linestyle="-.")

plt.grid(True,color='k')


plt.show()

# %%
# ex: đọc dữ liệu từ file data1.txt
# vẽ biểu đồ
#color :'c', 'm', 'y', 'k', 'r', 'g', 'b'
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import style

style.use('ggplot')

df = pd.read_csv("data1.txt", header=None, sep =",")


plt.plot(df[0],df[1], color="m")

plt.title('Line graph')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()

# %%
from cycler import cycler
cc = (cycler(color=list('rgb')) *
      cycler(linestyle=['-', '--', '-.']))
for d in cc:
    print(d)

# %%
line1, = plt.plot([1, 2, 3], label="Line 1", linestyle='--')
line2, = plt.plot([3, 2, 1], label="Line 2", linewidth=4)

# Create a legend for the first line.
first_legend = plt.legend(handles=[line1], loc=1)

# Add the legend manually to the current Axes.
ax = plt.gca().add_artist(first_legend)

# Create another legend for the second line.
plt.legend(handles=[line2], loc=4)

plt.show()
